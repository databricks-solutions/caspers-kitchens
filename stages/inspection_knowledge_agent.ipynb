# %% [markdown]
# ### Inspection Knowledge Agent
#
# Creates an Agent Bricks Knowledge Assistant over the food safety inspection
# report PDFs stored in the Unity Catalog volume. The Knowledge Assistant uses
# Databricks' Instructed Retriever to answer compliance and safety questions
# with citations from the original inspection documents.

# %%
# %pip install --upgrade databricks-sdk
dbutils.library.restartPython()

# %%
CATALOG = dbutils.widgets.get("CATALOG")
ENDPOINT_NAME = dbutils.widgets.get("INSPECTION_KNOWLEDGE_ENDPOINT_NAME")

# %%
from databricks.sdk import WorkspaceClient
import json

w = WorkspaceClient()

VOLUME_PATH = f"/Volumes/{CATALOG}/food_safety/reports"
AGENT_NAME = f"{CATALOG}-inspection-knowledge"
API_BASE = "/api/2.0/knowledge-assistants"

KA_BODY = {
    "name": AGENT_NAME,
    "description": (
        "Answers questions about food safety inspections at Caspers Kitchens "
        "ghost kitchen locations. Covers inspection scores, violations, "
        "corrective actions, and compliance status across all 8 locations (US + EMEA)."
    ),
    "endpoint_name": ENDPOINT_NAME,
    "knowledge_sources": [
        {
            "files_source": {
                "name": "inspection_reports",
                "type": "files",
                "files": {"path": VOLUME_PATH},
                "description": (
                    "Food safety inspection report PDFs for 8 ghost kitchen locations (US + EMEA) "
                    "(San Francisco, Silicon Valley, Bellevue, Chicago). Each PDF contains "
                    "the full inspection report with facility information, overall score, "
                    "letter grade, violation details, corrective actions, and follow-up status."
                ),
            },
        },
    ],
    "instructions": (
        "You are a food safety compliance assistant for Caspers Kitchens. "
        "Always cite the specific inspection report (location and date) when answering. "
        "Be precise about violation severities (critical, major, minor), corrective "
        "actions, and deadlines. Flag any critical violations prominently."
    ),
}

def get_tile_by_name(name):
    """Search all pages of /api/2.0/tiles for a tile with the given name."""
    try:
        params = {}
        while True:
            resp = w.api_client.do("GET", "/api/2.0/tiles", query=params)
            for tile in resp.get("tiles", []):
                if tile.get("name") == name:
                    return tile
            token = resp.get("next_page_token")
            if not token:
                break
            params = {"page_token": token}
    except Exception:
        pass
    return None

def find_existing_id():
    """Look up agent ID from uc_state."""
    try:
        df = spark.sql(f"""
            SELECT resource_data FROM {CATALOG}._internal_state.resources
            WHERE resource_type IN ('knowledge_assistants', 'endpoints')
            ORDER BY created_at DESC
        """)
        for row in df.collect():
            info = json.loads(row.resource_data)
            if info.get("endpoint_name") == ENDPOINT_NAME:
                return info.get("tile_id") or info.get("agent_id")
    except Exception:
        pass
    return None

agent_id = None
needs_polling = True

# Path 1: found ID in uc_state — trust it and update in place
existing_id = find_existing_id()
if existing_id:
    try:
        w.api_client.do("PUT", f"{API_BASE}/{existing_id}", body=KA_BODY)
        agent_id = existing_id
        print(f"✅ Updated existing Inspection KA: {agent_id}")
    except Exception as e:
        print(f"  PUT failed for {existing_id}: {e} — will try by name")

# Path 2: tile exists by name — trust it and update in place.
# Do NOT add a liveness check (ka_exists) here: a transient API error returns False,
# falls through to POST, and creates a new tile + a new MLflow experiment every run.
if not agent_id:
    tile = get_tile_by_name(AGENT_NAME)
    if tile:
        try:
            agent_id = tile["tile_id"]
            w.api_client.do("PUT", f"{API_BASE}/{agent_id}", body=KA_BODY)
            print(f"♻️ Updated existing Inspection KA by name: {agent_id}")
        except Exception as e:
            print(f"  PUT by name failed: {e} — will create new")
            agent_id = None

# Path 3: create new
if not agent_id:
    try:
        w.api_client.do("POST", API_BASE, body=KA_BODY)
        print(f"✅ Created Inspection Knowledge Assistant")
    except Exception as e:
        err = str(e)
        if "already exists" in err.lower() or "ALREADY_EXISTS" in err:
            print(f"♻️ Agent {AGENT_NAME} already exists (name collision), fetching ID")
        else:
            raise

    # Resolve tile_id — POST response doesn't include it
    import time as _time
    tile = get_tile_by_name(AGENT_NAME)
    if not tile:
        _time.sleep(10)
        tile = get_tile_by_name(AGENT_NAME)
    if tile:
        agent_id = tile["tile_id"]
        print(f"  Resolved tile_id: {agent_id}")
    else:
        agent_id = AGENT_NAME
        needs_polling = False
        print(f"⚠️ Could not resolve tile_id, using name as fallback")

print(f"   Agent ID (tile_id): {agent_id}")
print(f"   Endpoint: {ENDPOINT_NAME}")

# %%
import time

if needs_polling and agent_id and agent_id != AGENT_NAME:
    MAX_WAIT = 600
    POLL_INTERVAL = 30
    elapsed = 0
    print(f"Polling Inspection KA readiness (id={agent_id}, max {MAX_WAIT}s)...")

    while elapsed < MAX_WAIT:
        try:
            ka_status = w.api_client.do("GET", f"{API_BASE}/{agent_id}")
            ep_status = ka_status.get("knowledge_assistant", {}).get("status", {}).get("endpoint_status", "")
            print(f"  [{elapsed}s] endpoint_status: {ep_status}")
            if str(ep_status).upper() in ("ONLINE", "ACTIVE", "READY"):
                print(f"✅ Inspection Knowledge Assistant is READY")
                break
        except Exception as e:
            print(f"  [{elapsed}s] poll error: {type(e).__name__}: {e}")

        time.sleep(POLL_INTERVAL)
        elapsed += POLL_INTERVAL
    else:
        print(f"⏳ Endpoint may still be provisioning — proceeding.")
else:
    print(f"✅ Inspection Knowledge Assistant already running — skipping polling.")

# %%
import sys
sys.path.append('../utils')
from uc_state import add

add(CATALOG, "knowledge_assistants", {"endpoint_name": ENDPOINT_NAME, "tile_id": agent_id, "name": AGENT_NAME})
print("\u2705 Inspection Knowledge Agent stage complete")
